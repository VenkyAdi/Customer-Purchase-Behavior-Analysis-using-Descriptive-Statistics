# %% [markdown]
# <a href="https://colab.research.google.com/github/VenkyAdi/Customer-Purchase-Behavior-Analysis-using-Descriptive-Statistics/blob/main/Applied_Statistics_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Customer Purchase Behavior Analysis using Descriptive Statistics

# %% [markdown]
# ##Problem Statement

# %% [markdown]
# 🔍 **Problem Statement**:
#
# Welcome to the Probability and Statistics project! 📊🔍 In this exciting journey, you'll get the chance to apply the concepts you've learned in probability theory and statistics to analyze a real-world dataset. This project is your opportunity to dive deep into the world of data analysis and gain practical experience with the tools and techniques you've been learning. 🚀
#
# 🎯 **Objective**:
#
# Your mission is to analyze the provided dataset containing customer information and purchasing behavior to make informed decisions. Your goal is to identify patterns, trends, and correlations that will help your company optimize its marketing efforts and increase offer acceptance rates. 🎉

# %% [markdown]
# ##About the Dataset

# %% [markdown]
# Here's the link to the [dataset](https://docs.google.com/spreadsheets/d/12ln9iTNcVNOMYi_AU-OczKpa_KIP8XyVbsjk81Na8Yk/edit?usp=sharing)
#
#
# This data was gathered during last year's campaign.
# Data description is as follows;
#
# 1. Response (target) - 1 if customer accepted the offer in the last campaign, 0 otherwise
# 1. ID - Unique ID of each customer
# 1. Year_Birth - Age of the customer
# 1. Complain - 1 if the customer complained in the last 2 years
# 1. Dt_Customer - date of customer's enrollment with the company
# 1. Education - customer's level of education
# 1. Marital - customer's marital status
# 1. Kidhome - number of small children in customer's household
# 1. Teenhome - number of teenagers in customer's household
# 1. Income - customer's yearly household income
# 1. MntFishProducts - the amount spent on fish products in the last 2 years
# 1. MntMeatProducts - the amount spent on meat products in the last 2 years
# 1. MntFruits - the amount spent on fruits products in the last 2 years
# 1. MntSweetProducts - amount spent on sweet products in the last 2 years
# 1. MntWines - the amount spent on wine products in the last 2 years
# 1. MntGoldProds - the amount spent on gold products in the last 2 years
# 1. NumDealsPurchases - number of purchases made with discount
# 1. NumCatalogPurchases - number of purchases made using catalog (buying goods to be shipped through the mail)
# 1. NumStorePurchases - number of purchases made directly in stores
# 1. NumWebPurchases - number of purchases made through the company's website
# 1. NumWebVisitsMonth - number of visits to company's website in the last month
# 1. Recency - number of days since the last purchase

# %% [markdown]
# ##Task 1 - Basic CleanUp
#
# - **Clean and preprocess the dataset (handling missing values, data types, etc.).**
#
# - **Analyze the distribution of customer demographics (age, education, marital status) using descriptive statistics and visualizations.**

# %% [markdown]
# **Deliverables**:
#
# - **Cleaned and Preprocessed Dataset**:
#
#   Provide a detailed report on the steps taken to handle missing values, including imputation methods used if applicable.
#   Document the process of ensuring consistent data types for each variable, addressing any inconsistencies.
#
# - **Summary of Basic Statistics**:
#
#   Present calculated statistics such as mean, median, variance, and standard deviation for each relevant numerical variable.
#   Include a concise table or summary showcasing these measures for easy reference.

# %% [markdown]
# # **Library Imports**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Mount Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Read Data Set**

# %%
cs_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Customer_Purchase/Superstore Marketing Data .csv')
cs_df
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  84835.0        0
# 1         1        1961  Graduation         Single  57091.0        0
# 2     10476        1958  Graduation        Married  67267.0        0
# 3      1386        1967  Graduation       Together  32474.0        1
# 4      5371        1989  Graduation         Single  21474.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# 0            0   6/16/2014        0       189  ...              111
# ...

# %% [markdown]
# # **Customer Dataset Information**
# As we can see that there are particularly 22 data types having integer type data
# (16) float type data(1) and object type data (3)

# %%
cs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %% [markdown]
# # **Checking For Duplicate values**

# %%
dup = cs_df.duplicated()
print(dup)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2235    False
# 2236    False
# 2237    False
# 2238    False
# 2239    False
# Length: 2240, dtype: bool

# %%
dup = len(cs_df[cs_df.duplicated()])
print(dup)
# Out:
# 0

# %% [markdown]
# # **Checking For Missing Value**

# %%
cs_df.isnull().sum()
# Out:
# Id                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
# Income                 24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# Response                0
# Complain                0
# dtype: int64

# %% [markdown]
# # **Handle Missing , Null Values and Special Contains**

# %% [markdown]
# Droping Special Contains

# %%
cs_df = cs_df[~cs_df['Dt_Customer'].str.contains('########')]
cs_df
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  84835.0        0
# 1         1        1961  Graduation         Single  57091.0        0
# 2     10476        1958  Graduation        Married  67267.0        0
# 5      7348        1958         PhD         Single  71691.0        0
# 6      4073        1954    2n Cycle        Married  63564.0        0
# ...     ...         ...         ...            ...      ...      ...
# 2230   3363        1974    2n Cycle        Married  20130.0        0
# 2233   7829        1900    2n Cycle       Divorced  36640.0        1
# 2234   9977        1973  Graduation       Divorced  78901.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# 0            0   6/16/2014        0       189  ...              111
# ...

# %% [markdown]
# Filling The Missing Value

# %%
cs_df['Income'].fillna(value = 0, inplace = True)
cs_df.isnull().sum()
# Out:
# Id                     0
# Year_Birth             0
# Education              0
# Marital_Status         0
# Income                 0
# Kidhome                0
# Teenhome               0
# Dt_Customer            0
# Recency                0
# MntWines               0
# MntFruits              0
# MntMeatProducts        0
# MntFishProducts        0
# MntSweetProducts       0
# MntGoldProds           0
# NumDealsPurchases      0
# NumWebPurchases        0
# NumCatalogPurchases    0
# NumStorePurchases      0
# NumWebVisitsMonth      0
# Response               0
# Complain               0
# dtype: int64

# %% [markdown]
# # **Customer Age**

# %% [markdown]
# Convert Dt_Customer to datetime format as well before calculating the age of customer as Dt-Customer is a string data type

# %%
cs_df['Dt_Customer'] = pd.to_datetime(cs_df['Dt_Customer'])
# Out:
# <ipython-input-11-162c0809d518>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cs_df['Dt_Customer'] = pd.to_datetime(cs_df['Dt_Customer'])

# %%
from datetime import datetime

cs_df['Year_Birth'] =  pd.to_datetime(cs_df['Year_Birth'],format='%Y')

cs_df['Age'] = (cs_df['Dt_Customer'] - cs_df['Year_Birth']).astype('<m8[Y]')

cs_df.head()
# Out:
# <ipython-input-12-562217221c01>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cs_df['Year_Birth'] =  pd.to_datetime(cs_df['Year_Birth'],format='%Y')
# <ipython-input-12-562217221c01>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cs_df['Age'] = (cs_df['Dt_Customer'] - cs_df['Year_Birth']).astype('<m8[Y]')
#       Id Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826 1970-01-01  Graduation       Divorced  84835.0        0         0
# ...

# %% [markdown]
# # **Cleaned Data Set**

# %%
cs_df
# Out:
#          Id Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0      1826 1970-01-01  Graduation       Divorced  84835.0        0         0
# 1         1 1961-01-01  Graduation         Single  57091.0        0         0
# 2     10476 1958-01-01  Graduation        Married  67267.0        0         1
# 5      7348 1958-01-01         PhD         Single  71691.0        0         0
# 6      4073 1954-01-01    2n Cycle        Married  63564.0        0         0
# ...     ...        ...         ...            ...      ...      ...       ...
# 2230   3363 1974-01-01    2n Cycle        Married  20130.0        0         0
# 2233   7829 1900-01-01    2n Cycle       Divorced  36640.0        1         0
# 2234   9977 1973-01-01  Graduation       Divorced  78901.0        0         1
# 2236   5263 1977-01-01    2n Cycle        Married  31056.0        1         0
# 2238    528 1978-01-01  Graduation        Married  65819.0        0         0
#
# ...

# %%
cust_age = cs_df['Year_Birth'].value_counts()
cust_age.head(15)
# Out:
# 1971-01-01    57
# 1975-01-01    53
# 1969-01-01    51
# 1972-01-01    49
# 1970-01-01    48
# 1976-01-01    47
# 1965-01-01    45
# 1974-01-01    43
# 1973-01-01    43
# 1959-01-01    39
# 1956-01-01    34
# 1952-01-01    32
# 1978-01-01    32
# 1963-01-01    31
# 1967-01-01    31
# Name: Year_Birth, dtype: int64

# %%
education = cs_df['Education'].value_counts()
education
# Out:
# Graduation    686
# PhD           273
# Master        224
# 2n Cycle      105
# Basic          36
# Name: Education, dtype: int64

# %%
martial = cs_df['Marital_Status'].value_counts()
martial
# Out:
# Married     505
# Together    343
# Single      285
# Divorced    151
# Widow        36
# YOLO          2
# Alone         1
# Absurd        1
# Name: Marital_Status, dtype: int64

# %%
demo_var = ['Age','Education','Income','Marital_Status']

fig, axes = plt.subplots(nrows = 2, ncols = 2, figsize = (13,10))
fig.suptitle('Demographics Distributions of the Important Variables', y = 0.96,color = 'black', fontsize = 20)

axes = axes.flatten()

for i, var in enumerate(cs_df[demo_var]):
  if var == 'Age':
    sns.boxplot(x=var,data = cs_df, ax=axes[i],color = '#9370DB')

  elif var == 'Education':
    sns.countplot(x=var, data=cs_df, ax=axes[i],color = '#9370DB')

  elif var == 'Income':
    sns.histplot(cs_df[var],kde = True, ax = axes[i],color = '#9370DB')

  else:
    sns.barplot(x = cs_df[var].value_counts().index, y = cs_df[var].value_counts().values,color = '#9370DB')

for i in range(len(cs_df[demo_var]), len(axes)):
  fig.delaxes(axes[i])

plt.tight_layout
plt.show()

# %% [markdown]
# ##Task 2 - Descriptive Statistics 📊
#
# - **Calculate measures of central tendency (mean, median, mode) and measures of dispersion (variance, standard deviation) for key variables. Identify and handle outliers if necessary.**

# %% [markdown]
# **Deliverables**:
#
# - **Descriptive statistics that reveal the central tendencies, variations, and potential outliers in the dataset.**:

# %% [markdown]
# # **Central Tendency**

# %% [markdown]
#  **Central Tendency includes finding out the mean median mode from the key variables**

# %% [markdown]
# **Mean**

# %%
demo_var = ['Age','Income','Recency','MntWines','MntFruits','MntMeatProducts','MntFishProducts','NumDealsPurchases','MntGoldProds','NumWebPurchases','NumWebVisitsMonth']
d_mean = cs_df[demo_var].mean()
print(d_mean)
# Out:
# Age                     44.355740
# Income               50924.772659
# Recency                 49.348187
# MntWines               301.964502
# MntFruits               25.218278
# MntMeatProducts        162.177492
# MntFishProducts         36.485650
# NumDealsPurchases        2.325529
# MntGoldProds            44.107251
# NumWebPurchases          4.092145
# NumWebVisitsMonth        5.409366
# dtype: float64

# %% [markdown]
# **Median**

# %%
demo_var = ['Age','Income','Recency','MntWines','MntFruits','MntMeatProducts','MntFishProducts','NumDealsPurchases','MntGoldProds','NumWebPurchases','NumWebVisitsMonth']
d_median = cs_df[demo_var].median()
print(d_median)
# Out:
# Age                     43.0
# Income               50166.5
# Recency                 50.0
# MntWines               171.0
# MntFruits                7.0
# MntMeatProducts         65.5
# MntFishProducts         11.0
# NumDealsPurchases        2.0
# MntGoldProds            24.5
# NumWebPurchases          4.0
# NumWebVisitsMonth        6.0
# dtype: float64

# %% [markdown]
# **Mode**

# %%
demo_var = ['Age','Income','Recency','MntWines','MntFruits','MntMeatProducts','MntFishProducts','NumDealsPurchases','MntGoldProds','NumWebPurchases','NumWebVisitsMonth']
d_mode = cs_df[demo_var].mode()
print(d_mode)
# Out:
#     Age  Income  Recency  MntWines  MntFruits  MntMeatProducts  \
# 0  41.0     0.0     65.0       2.0        0.0             11.0
# 1   NaN     NaN      NaN       NaN        NaN              NaN
#
#    MntFishProducts  NumDealsPurchases  MntGoldProds  NumWebPurchases  \
# 0              0.0                1.0             1              1.0
# 1              NaN                NaN             3              NaN
#
#    NumWebVisitsMonth
# 0                7.0
# 1                NaN

# %% [markdown]
# **Measures of Dispersion (Variance and Standard Deviation)**

# %%
demo_var = ['Age','Income','Recency','MntWines','MntFruits','MntMeatProducts','MntFishProducts','NumDealsPurchases','MntGoldProds','NumWebPurchases','NumWebVisitsMonth']
d_var = cs_df[demo_var].var()
print(d_var)
# Out:
# Age                  1.476791e+02
# Income               4.607477e+08
# Recency              8.303541e+02
# MntWines             1.145089e+05
# MntFruits            1.489002e+03
# MntMeatProducts      4.805031e+04
# MntFishProducts      2.962155e+03
# NumDealsPurchases    3.672485e+00
# MntGoldProds         2.785360e+03
# NumWebPurchases      7.701253e+00
# NumWebVisitsMonth    5.935090e+00
# dtype: float64

# %%
demo_var = ['Age','Income','Recency','MntWines','MntFruits','MntMeatProducts','MntFishProducts','NumDealsPurchases','MntGoldProds','NumWebPurchases','NumWebVisitsMonth']
d_std = cs_df[demo_var].std()
print(d_std)
# Out:
# Age                     12.152329
# Income               21465.033515
# Recency                 28.815866
# MntWines               338.391676
# MntFruits               38.587591
# MntMeatProducts        219.203801
# MntFishProducts         54.425681
# NumDealsPurchases        1.916373
# MntGoldProds            52.776506
# NumWebPurchases          2.775113
# NumWebVisitsMonth        2.436204
# dtype: float64

# %% [markdown]
# **Finding out Outliers and Handle the Outliers Using Box-Plot**

# %%
demo_var = ['Income', 'Age', 'MntWines', 'MntFruits', 'MntMeatProducts','Recency']

len_var = len(demo_var)

r_num = (len_var + 1) // 2

fig,axes = plt.subplots(nrows = r_num , ncols = 2 , figsize = (12,8))

axes = axes.flatten()

for i,var in enumerate(demo_var):
  sns.boxplot(x = var, data = cs_df, ax= axes[i], color = '#9370DB')
  axes[i].set_title(f'Boxplot of {var}:', y = 0.98, color = 'black',fontsize = 15)

plt.tight_layout()
plt.show()

# %%
columns_with_outliers = ['Income', 'Age', 'MntWines', 'MntFruits', 'MntMeatProducts']

def remove_outliers(data, columns):

    for column in columns:
        Q1 = data[column].quantile(0.20)
        Q3 = data[column].quantile(0.80)
        IQR = Q3 - Q1


        lower_limit = Q1 - 1.5 * IQR
        upper_limit = Q3 + 1.5 * IQR


        data = data[(data[column] >= lower_limit) & (data[column] <= upper_limit)]

    return data


df_new = remove_outliers(cs_df, columns_with_outliers)

# %%
d_variables = ['Income', 'Age', 'Recency']

num_variables = len(d_variables)

fig, axes = plt.subplots(nrows=  2, ncols=2, figsize=(12, 7))

axes = axes.flatten()

for i, variable in enumerate(d_variables):
    sns.boxplot(x=variable, data=df_new, ax=axes[i],color = '#9370DB')
    axes[i].set_title(f'Boxplot of {variable}')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Here are some of the other important columns with minor outliers but can be considerd as anamolies**

# %%
numerical_column = ['NumDealsPurchases', 'NumWebPurchases',
                              'NumCatalogPurchases', 'NumStorePurchases',
                              'NumWebVisitsMonth']

len_var = len(numerical_column)

r_num = (len_var + 1) // 2

fig,axes = plt.subplots(nrows = r_num , ncols = 2 , figsize = (16,10))

axes = axes.flatten()

for i,var in enumerate(numerical_column):
  sns.boxplot(x = var, data = cs_df, ax= axes[i], color = '#9370DB')
  axes[i].set_title(f'Boxplot of {var}:', y = 0.99, color = 'black',fontsize = 15)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Task 3 - Probability Distributions 🎲
#
# - **Identify variables that could follow specific probability distributions (e.g., Binomial, Normal). Calculate probabilities and expected values based on these distributions.**

# %% [markdown]
# **Deliverables**:
#
# - **Determination of suitable probability distributions for relevant variables and corresponding calculated probabilities and expected values.**:

# %%
import numpy as np
import scipy.stats as stats

dis_var = ['Age','Recency','Income']

fig, axes = plt.subplots(nrows = 2, ncols = 2, figsize = (12,8))
fig.suptitle(" Normal Distribution curves", y = 0.98, color = 'black')

axes = axes.flatten()

for i , var in enumerate(dis_var):
  sns.histplot(df_new[var], kde = True, ax = axes[i], color = '#9370DB')
  axes[i].set_title(f'Distribution of {var}:')

for i in range(len(dis_var), len(axes)):
  fig.delaxes(axes[i])

plt.tight_layout()
plt.show()

# %% [markdown]
# # **Probability and Expected Value**

# %%
import numpy as np
from scipy.stats import norm

# %%
m_recency = np.mean(df_new['Recency'])
std_recency = np.std(df_new['Recency'])

prob_less_20 = norm.cdf(20, loc = m_recency, scale = std_recency)
prob_grt_40 = 1- norm.cdf(40,loc = m_recency , scale = std_recency)

print(f"Probability of recency less than 20: {prob_less_20:.2f}")
print(f"Probability of recency greater than 40: {prob_grt_40:.2f}")

expected_recency = m_recency
print(f"The expected_recency is: {expected_recency:.2f}")

plt.figure(figsize=(8, 6))
plt.boxplot(df_new['Recency'],patch_artist=True, boxprops=dict(facecolor="#9370DB", color="#9370DB"))
plt.title('Box plot of Recency')
plt.xlabel('Recency')
plt.ylabel('Values')
plt.axhline(y=expected_recency, color='black', linestyle='--', label='Expected Recency')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Probability of recency less than 20: 0.16
# Probability of recency greater than 40: 0.62
# The expected_recency is: 48.99

# %%
m_sal = np.mean(df_new['Income'])
std_sal = np.std(df_new['Income'])

prob_less_40000 = norm.cdf(40000, loc = m_sal, scale = std_sal)
prob_grt_60000 = 1- norm.cdf(60000,loc = m_sal , scale = std_sal)

print(f"Probability of income less than 40000$: {prob_less_40000:.3f}")
print(f"Probability of income greater than 60000$: {prob_grt_60000:.3f}")

expected_salary = m_sal
print(f"The expected income is: {expected_salary:.2f}")

plt.figure(figsize=(8, 6))
plt.boxplot(df_new['Income'],patch_artist=True, boxprops=dict(facecolor="#9370DB", color="#9370DB"))
plt.title('Box plot of Income')
plt.xlabel('Income')
plt.ylabel('Income')
plt.axhline(y=expected_salary, color='black', linestyle='--', label='Expected Income')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Probability of income less than 40000$: 0.359
# Probability of income greater than 60000$: 0.252
# The expected income is: 47035.47

# %%
m_age = np.mean(df_new['Age'])
std_age = np.std(df_new['Age'])

prob_less_30 = norm.cdf(30, loc = m_age, scale = std_age)
prob_grt_50 = 1- norm.cdf(50,loc = m_age , scale = std_age)

print(f"Probability of age less than 30: {prob_less_30:.2f}")
print(f"Probability of age greater than 50: {prob_grt_50:.2f}")

expected_age = m_age
print(f"The expected age is: {expected_age:.2f}")

plt.figure(figsize=(8, 6))
plt.boxplot(df_new['Age'],patch_artist=True, boxprops=dict(facecolor="#9370DB", color="#9370DB"))
plt.title('Box plot of Age')
plt.xlabel('Age')
plt.ylabel('Age')
plt.axhline(y=expected_age, color='black', linestyle='--', label='Expected Age')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Probability of age less than 30: 0.11
# Probability of age greater than 50: 0.30
# The expected age is: 44.12

# %% [markdown]
# ## **Binomial Distribution**

# %%
Bio_var = ['Response','Complain']

fig, axes = plt.subplots(nrows = 2, ncols = 2, figsize = (12,8))
fig.suptitle("Binomial Distribution ", y = 0.98, color = 'black')

axes = axes.flatten()

for i , var in enumerate(Bio_var):
  sns.histplot(df_new[var], kde = True, ax = axes[i], color = '#9370DB')
  axes[i].set_title(f'Distribution of {var}:')

for i in range(len(Bio_var), len(axes)):
  fig.delaxes(axes[i])

plt.tight_layout()
plt.show()

# %%
from scipy.stats import binom

num_response = len(cs_df['Response'])
success_response = np.mean(cs_df['Response'])
k1 = np.sum(cs_df['Response'] == 1)


num_Complain = len(cs_df['Complain'])
success_Complain = np.mean(cs_df['Complain'])
k2 = np.sum(cs_df['Complain'] == 1)



prob_response = binom.pmf(k1,num_response,success_response)
prob_complain = binom.pmf(k2,num_Complain,success_Complain)

print(f"The probability of Response being 1 : {prob_response:.2f}")
print(f"The probability of Complain being 1 : {prob_complain:.2f}")



expected_response = num_response * success_response
expected_complain = num_Complain * success_Complain

print(f"The Expected value of Response is : {expected_response:.2f}")
print(f"The Expected value of Complain is: {expected_complain:.2f}")
# Out:
# The probability of Response being 1 : 0.03
# The probability of Complain being 1 : 0.11
# The Expected value of Response is : 200.00
# The Expected value of Complain is: 12.00

# %% [markdown]
# ## Task 4: Insights and Customer Segmentation 📈
#
# - **Explore relationships between customer characteristics and spending habits. Segment customers based on their behaviors and characteristics.**

# %% [markdown]
# **Deliverables**:
#
# - **Key insights regarding relationships between variables and distinct customer segments based on behaviors.**

# %% [markdown]
# # **Correlation HeatMap based on insights**

# %%
correlation_matrix = df_new.corr().round(2)
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='BuPu', linewidths=0.4)
plt.title('Correlation Heatmap')
plt.show()
# Out:
# <ipython-input-39-f8345a182a4f>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df_new.corr().round(2)

# %% [markdown]
# # **Age Distrubution based on Income**

# %%
plt.style.use('seaborn-darkgrid')


plt.figure(figsize=(12, 6))


sns.lineplot(x='Age', y='Income', data=df_new, color='#5E2A7E', marker='o', markersize=8, linewidth=2)


plt.title("Age vs Income Distribution", fontsize=18)
plt.xlabel('Age', fontsize=14)
plt.ylabel('Income', fontsize=14)


plt.legend(['Income'], loc='upper right', fontsize=12)


plt.grid(True, linestyle='--', alpha=0.7)


plt.xticks(fontsize=12)
plt.yticks(fontsize=12)


plt.tight_layout()
plt.show()
# Out:
# <ipython-input-72-d2d26078377c>:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')

# %% [markdown]
# # **Total Spending**

# %%
df_new["Total_Amount_Spent"] = df_new[["MntWines", "MntFruits", "MntMeatProducts",
                                       "MntFishProducts", "MntSweetProducts",
                                       "MntGoldProds"]].sum(axis=1)


plt.figure(figsize=(12, 6))


sns.scatterplot(data=df_new, x='Income', y='Total_Amount_Spent', color='#9370DB', alpha=0.7, s=100)


plt.title('Income Incured and Amount Spent', fontsize=16)
plt.xlabel('Income', fontsize=14)
plt.ylabel('Total Amount Spent', fontsize=14)


plt.grid(True, linestyle='--', alpha=0.5)


plt.xticks(fontsize=12)
plt.yticks(fontsize=12)


plt.tight_layout()
plt.show()

# %%
months = ['January', 'February', 'March', 'April', 'May', 'June',
          'July', 'August', 'September', 'October', 'November', 'December']


df_new['month'] = pd.Categorical(df_new['month'], categories=months, ordered=True)


plt.figure(figsize=(12, 6))

sns.set_style("whitegrid")
sns.barplot(x='month', y='NumWebPurchases', data=df_new.groupby('month')['NumWebPurchases'].sum().reset_index(), palette='BuPu')


plt.title("Number of Purchases Made Across the Months Through Website", fontsize=18)
plt.xlabel('Month', fontsize=14)
plt.ylabel('Number of Purchases', fontsize=14)

plt.xticks()


plt.xticks(fontsize=12)
plt.yticks(fontsize=12)


plt.tight_layout()
plt.show()
# Out:
# <ipython-input-94-1eb1483eef11>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='month', y='NumWebPurchases', data=df_new.groupby('month')['NumWebPurchases'].sum().reset_index(), palette='BuPu')

# %%
sns.set_style("whitegrid")

plt.figure(figsize=(12, 8))
sns.countplot(x='Education', data=df_new, hue='Marital_Status', palette='BuPu')
plt.title("Marital Status Distribution Based on Education Count", fontsize=16)
plt.xlabel('Education', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.legend(fontsize=12)
plt.show()

# %% [markdown]
# ## Task 5: Conclusion and Recommendations
#
# - **Create clear visualizations to showcase your findings. Use insights to make recommendations for the company based on your analysis.**

# %% [markdown]
# **Deliverables**:
#
# - **Well-designed visualizations that visually represent your insights and actionable recommendations based on customer behavior analysis.**

# %% [markdown]
# Examining customer demographics, several key insights emerge. Firstly, the age distribution reveals that the majority of customers fall within the 25 to 54 age range, suggesting a prime target demographic for marketing efforts. Secondly, an analysis of education levels indicates that most customers hold a degree, highlighting a potentially well-educated and affluent customer base. Furthermore, marital status data shows that a significant portion of customers are married, indicating potential opportunities for family-oriented marketing strategies.
#
# Moving on to financial aspects, the income distribution skews to the right, indicating the presence of a few customers with exceptionally high incomes. This suggests the possibility of catering to high-end clientele alongside the broader customer base. Additionally, notable outliers exist in critical columns, such as income and expenditure patterns, reflecting diverse spending habits among customers. This underscores the importance of understanding and accommodating varying customer needs and preferences.
#
# Furthermore, the likelihood of a customer making a purchase stands at 50%, indicating a balanced probability. This insight can inform marketing strategies to effectively target potential customers and optimize conversion rates.
#
# In conclusion, these insights provide a comprehensive understanding of the customer base, offering valuable guidance for tailored marketing approaches and personalized offerings. By leveraging these insights, businesses can better connect with their target audience and drive growth and customer satisfaction.

# %% [markdown]
# # **Recommendation**

# %% [markdown]
# **Targeted Marketing Strategies:**
#
# Opportunity to deploy focused marketing initiatives, emphasizing high-end products, exclusive loyalty programs, and personalized recommendations. By tailoring campaigns to meet the preferences of this affluent segment, we can enhance brand engagement and drive increased sales.
#
# **Enhanced Online Experience:**
#
# To capitalize on the higher online purchasing behavior observed in Cluster 0 and Cluster 2, strategic enhancements to the company's website are warranted. By optimizing user experience and offering compelling digital content, we can attract and retain these customers, fostering long-term loyalty and repeat business.
#
# **Diversification of Product Offerings:**
#
# Identifying categories with high demand across all clusters, such as wines and meat products, presents an opportunity for expansion. By broadening our product range to meet diverse consumer preferences, we can capture additional market share and drive revenue growth.
#
# **Customer Retention Strategies:**
#
# Addressing customer complaints and enhancing overall satisfaction levels are critical for customer retention. By implementing proactive measures to resolve issues and enhance service quality, we can strengthen customer loyalty and encourage repeat purchases, ultimately driving long-term profitability.
#
# **Insights into Customer Behavior:**
#
# The relatively low offer acceptance rate indicates a need for targeted marketing campaigns that resonate with customer preferences and interests. Additionally, the correlation between higher education levels and incomes suggests potential segments for premium product offerings, warranting further exploration and strategic positioning.

# %% [markdown]
# ## Bonus Task - Geogebra Experiment

# %% [markdown]
# Here's the link to an intriguing GeoGebra experiment: [GeoGebra Experiment Link](https://www.geogebra.org/m/LZbwMZtJ)
#
# This experiment lets you simulate coin flips as per your preferences and specifications!
#
# Your task involves recording a video where you'll explain the concept of the **Law of Large Numbers** using this experiment. Dive further into the experience by adjusting the number of coins and exploring varying coin biases. 🪙📹🔍
